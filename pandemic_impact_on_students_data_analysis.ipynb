# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Survey_Data_Analysis.csv")

# %%
df.head()
# Out:
#               Age        Educational_level Screening_time doubts_frequency  \
# 0  16 to 18 years  Higher Secondary School   3 to 4 hours           Rarely
# 1  16 to 18 years  Higher Secondary School   2 to 3 hours           Always
# 2  16 to 18 years  Higher Secondary School   4 to 5 hours        Sometimes
# 3  16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
# 4  16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
#
#   doubts_clearance_frequency assignments_deadlines  hobby_hours  \
# 0                     Always                 Never            1
# 1                     Always             Sometimes            1
# 2                  Sometimes             Sometimes            0
# 3                  Sometimes                 Never            1
# 4                     Always             Sometimes            2
#
#   health_problems lack_of_practical_exposure Irregular_eating_habits  ...  \
# ...

# %%
df
# Out:
#                  Age        Educational_level Screening_time doubts_frequency  \
# 0     16 to 18 years  Higher Secondary School   3 to 4 hours           Rarely
# 1     16 to 18 years  Higher Secondary School   2 to 3 hours           Always
# 2     16 to 18 years  Higher Secondary School   4 to 5 hours        Sometimes
# 3     16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
# 4     16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
# ...              ...                      ...            ...              ...
# 1095  18 to 22 years           Under Graduate   4 to 5 hours           Always
# 1096  13 to 15 years         Secondary School   2 to 3 hours           Rarely
# 1097  23 to 26 years            Post Graduate   5 to 6 hours        Sometimes
# 1098  23 to 26 years            Post Graduate   5 to 6 hours        Sometimes
# 1099  23 to 26 years            Post Graduate   5 to 6 hours        Sometimes
#
# ...

# %%
df.describe()
# Out:
#        hobby_hours  \
# count  1100.000000
# mean      0.958182
# std       0.776167
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000
#
#        increased_sleep_hours                                                                                                                            \
# count                                        1100.000000
# mean                                            1.891818
# std                                             1.266969
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             4.000000
#
#        online_difficulty_level  focus_level  concentration_difficulty  \
# count              1100.000000  1100.000000               1100.000000
# ...

# %%
df.shape
# Out:
# (1100, 23)

# %%
df.isnull().sum()
# Out:
# Age                                                                                                                                                 0
# Educational_level                                                                                                                                   0
# Screening_time                                                                                                                                      0
# doubts_frequency                                                                                                                                    0
# doubts_clearance_frequency                                                                                                                          0
# assignments_deadlines                                                                                                                               0
# ...

# %%
df1=df.fillna(0)

# %%
df1.isnull().sum()
# Out:
# Age                                                                                                                                                0
# Educational_level                                                                                                                                  0
# Screening_time                                                                                                                                     0
# doubts_frequency                                                                                                                                   0
# doubts_clearance_frequency                                                                                                                         0
# assignments_deadlines                                                                                                                              0
# ...

# %%
df1.to_csv('finalanalysis.csv',index=False)

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 6C70-2416
#
#  Directory of C:\Users\Admin
#
# 15-04-2022  19:36    <DIR>          .
# 11-01-2022  12:40    <DIR>          ..
# 27-03-2022  20:49    <DIR>          .android
# 07-08-2020  17:53    <DIR>          .AndroidStudio4.0
# 26-02-2021  14:09    <DIR>          .atom
# 02-09-2021  17:21             2,781 .bash_history
# 22-07-2021  11:29    <DIR>          .cache
# 21-09-2020  14:55    <DIR>          .conda
# 21-09-2020  14:44                43 .condarc
# 09-10-2021  23:32    <DIR>          .config
# 14-09-2020  15:54                16 .emulator_console_auth_token
# 12-03-2022  16:31                60 .gitconfig
# 14-09-2020  16:52    <DIR>          .gradle
# 20-07-2020  17:46    <DIR>          .idea
# 13-02-2021  11:49    <DIR>          .idlerc
# 15-04-2022  18:37    <DIR>          .ipynb_checkpoints
# 21-09-2020  14:45    <DIR>          .ipython
# 03-08-2020  19:29    <DIR>          .jdks
# ...

# %% [markdown]
# # EDA

# %%
df1=pd.read_csv('finalanalysis.csv')

# %%
df
# Out:
#                  Age        Educational_level Screening_time doubts_frequency  \
# 0     16 to 18 years  Higher Secondary School   3 to 4 hours           Rarely
# 1     16 to 18 years  Higher Secondary School   2 to 3 hours           Always
# 2     16 to 18 years  Higher Secondary School   4 to 5 hours        Sometimes
# 3     16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
# 4     16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
# ...              ...                      ...            ...              ...
# 1095  18 to 22 years           Under Graduate   4 to 5 hours           Always
# 1096  13 to 15 years         Secondary School   2 to 3 hours           Rarely
# 1097  23 to 26 years            Post Graduate   5 to 6 hours        Sometimes
# 1098  23 to 26 years            Post Graduate   5 to 6 hours        Sometimes
# 1099  23 to 26 years            Post Graduate   5 to 6 hours        Sometimes
#
# ...

# %%
pd.set_option('display.max_rows',df1.shape[0]+1)
df1
# Out:
#                  Age        Educational_level Screening_time doubts_frequency  \
# 0     16 to 18 years  Higher Secondary School   3 to 4 hours           Rarely
# 1     16 to 18 years  Higher Secondary School   2 to 3 hours           Always
# 2     16 to 18 years  Higher Secondary School   4 to 5 hours        Sometimes
# 3     16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
# 4     16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
# 5     16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
# 6     16 to 18 years  Higher Secondary School   2 to 3 hours           Rarely
# 7     18 to 22 years           Under Graduate   2 to 3 hours        Sometimes
# 8     18 to 22 years           Under Graduate   4 to 5 hours           Rarely
# 9     13 to 15 years         Secondary School   2 to 3 hours        Sometimes
# 10    16 to 18 years  Higher Secondary School   3 to 4 hours        Sometimes
# ...

# %%
df1.select_dtypes(include=['object'])
# Out:
#                  Age        Educational_level Screening_time doubts_frequency  \
# 0     16 to 18 years  Higher Secondary School   3 to 4 hours           Rarely
# 1     16 to 18 years  Higher Secondary School   2 to 3 hours           Always
# 2     16 to 18 years  Higher Secondary School   4 to 5 hours        Sometimes
# 3     16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
# 4     16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
# 5     16 to 18 years  Higher Secondary School   4 to 5 hours           Rarely
# 6     16 to 18 years  Higher Secondary School   2 to 3 hours           Rarely
# 7     18 to 22 years           Under Graduate   2 to 3 hours        Sometimes
# 8     18 to 22 years           Under Graduate   4 to 5 hours           Rarely
# 9     13 to 15 years         Secondary School   2 to 3 hours        Sometimes
# 10    16 to 18 years  Higher Secondary School   3 to 4 hours        Sometimes
# ...

# %% [markdown]
# # Heatmap

# %%
corr=df.corr()
corr
# Out:
#                                                     hobby_hours  \
# hobby_hours                                            1.000000
# increased_sleep_hours                          ...     0.778197
# online_difficulty_level                               -0.158946
# focus_level                                           -0.369102
# concentration_difficulty                              -0.366464
# procrastination                                        0.115347
# social_media_hours                                     0.391665
#
#                                                     increased_sleep_hours                                                                                                                            \
# hobby_hours                                                                                  0.778197
# increased_sleep_hours                          ...                                           1.000000
# ...

# %%
sns.heatmap(corr)

# %% [markdown]
# # Using Pandas Profiling library

# %%
from pandas_profiling import ProfileReport

# %%
profile=ProfileReport(df1,title='Impact of Pandemic on Students Mental Health')

# %%
profile.to_file(output_file='Covid19_data_report.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
